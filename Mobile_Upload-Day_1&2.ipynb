# %%
# %config IPCompleter.greedy=True
# !python --version
# Out:
# Python 3.7.4

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# !pwd
# Out:
# /Users/danielchan/Dropbox/Mobile_Upload

# %%
df = pd.read_csv('./Validations and Submissions as of 10302019 10_35_AM.csv', index_col=None)

# %%
df.head()
# Out:
#    MOBILE_APP_REQUEST_ID            INSERT_TS  RESPONSE_STATUS_ID  \
# 0                    338  2019-10-28 02:02:27              300100
# 1                    343  2019-10-28 07:25:18              300100
# 2                    352  2019-10-28 08:05:07              300100
# 3                    365  2019-10-28 08:32:42              300100
# 4                    368  2019-10-28 08:33:43              300200
#
#            DEVICE DEVICE_OS            RESPONSE_STATUS_NAME  \
# 0  iPhone 6s Plus    13.1.3          Successful validation.
# 1       SM-N960U1        28          Successful validation.
# 2        SM-G960U        28          Successful validation.
# 3        SM-G960U        28          Successful validation.
# 4        SM-G960U        28  INFORMATION_NOT_VERIFIED_TITLE
#
#   MOBILE_SUBMISSION_ID Size Page Count          INSERT_TS.1  \
# 0                  NaN  NaN        NaN  2019-10-28 02:02:27
# 1                  NaN  NaN        NaN  2019-10-28 07:25:18
# 2                  NaN  NaN        NaN  2019-10-28 08:05:07
# 3                  NaN  NaN        NaN  2019-10-28 08:32:42
# 4                  NaN  NaN        NaN  2019-10-28 08:33:43
#
#         LAST_UPDATE_TS      CLIENT_VERSION
# 0  2019-10-28 02:02:29  1.0.201910230000.2
# 1  2019-10-28 07:25:21                 1.0
# 2  2019-10-28 08:05:12                 1.0
# 3  2019-10-28 08:32:46                 1.0
# 4  2019-10-28 08:33:47                 1.0

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.dtypes
# Out:
# MOBILE_APP_REQUEST_ID     int64
# INSERT_TS                object
# RESPONSE_STATUS_ID        int64
# DEVICE                   object
# DEVICE_OS                object
# RESPONSE_STATUS_NAME     object
# MOBILE_SUBMISSION_ID     object
# Size                     object
# Page Count               object
# INSERT_TS.1              object
# LAST_UPDATE_TS           object
# CLIENT_VERSION           object
# dtype: object

# %%
# convert INSERT_TS, INSERT_TS.1 and LAST_UPDATE_TS to datetime
df['INSERT_TS'] = pd.to_datetime(df['INSERT_TS'])
df['INSERT_TS.1'] = pd.to_datetime(df['INSERT_TS.1'])
df['LAST_UPDATE_TS'] = pd.to_datetime(df['LAST_UPDATE_TS'])

# %%
df.dtypes
# Out:
# MOBILE_APP_REQUEST_ID             int64
# INSERT_TS                datetime64[ns]
# RESPONSE_STATUS_ID                int64
# DEVICE                           object
# DEVICE_OS                        object
# RESPONSE_STATUS_NAME             object
# MOBILE_SUBMISSION_ID             object
# Size                             object
# Page Count                       object
# INSERT_TS.1              datetime64[ns]
# LAST_UPDATE_TS           datetime64[ns]
# CLIENT_VERSION                   object
# dtype: object

# %%
df['INSERT_TS'].dt.time
# Out:
# 0      02:02:27
# 1      07:25:18
# 2      08:05:07
# 3      08:32:42
# 4      08:33:43
#          ...
# 995    12:38:43
# 996    12:38:53
# 997    12:38:56
# 998    12:39:18
# 999    12:41:31
# Name: INSERT_TS, Length: 1000, dtype: object

# %%
df.head()
# Out:
#    MOBILE_APP_REQUEST_ID           INSERT_TS  RESPONSE_STATUS_ID  \
# 0                    338 2019-10-28 02:02:27              300100
# 1                    343 2019-10-28 07:25:18              300100
# 2                    352 2019-10-28 08:05:07              300100
# 3                    365 2019-10-28 08:32:42              300100
# 4                    368 2019-10-28 08:33:43              300200
#
#            DEVICE DEVICE_OS            RESPONSE_STATUS_NAME  \
# 0  iPhone 6s Plus    13.1.3          Successful validation.
# 1       SM-N960U1        28          Successful validation.
# 2        SM-G960U        28          Successful validation.
# 3        SM-G960U        28          Successful validation.
# 4        SM-G960U        28  INFORMATION_NOT_VERIFIED_TITLE
#
#   MOBILE_SUBMISSION_ID Size Page Count         INSERT_TS.1  \
# 0                  NaN  NaN        NaN 2019-10-28 02:02:27
# 1                  NaN  NaN        NaN 2019-10-28 07:25:18
# 2                  NaN  NaN        NaN 2019-10-28 08:05:07
# 3                  NaN  NaN        NaN 2019-10-28 08:32:42
# 4                  NaN  NaN        NaN 2019-10-28 08:33:43
#
#        LAST_UPDATE_TS      CLIENT_VERSION
# 0 2019-10-28 02:02:29  1.0.201910230000.2
# 1 2019-10-28 07:25:21                 1.0
# 2 2019-10-28 08:05:12                 1.0
# 3 2019-10-28 08:32:46                 1.0
# 4 2019-10-28 08:33:47                 1.0

# %%
df.tail(10)
# Out:
#      MOBILE_APP_REQUEST_ID           INSERT_TS  RESPONSE_STATUS_ID  \
# 990                   2888 2019-10-29 12:36:47              300100
# 991                   2891 2019-10-29 12:37:25              300100
# 992                   2892 2019-10-29 12:37:34              400100
# 993                   2893 2019-10-29 12:37:37              400100
# 994                   2896 2019-10-29 12:37:49              300200
# 995                   2897 2019-10-29 12:38:43              300100
# 996                   2898 2019-10-29 12:38:53              300100
# 997                   2899 2019-10-29 12:38:56              300100
# 998                   2900 2019-10-29 12:39:18              400100
# 999                   2905 2019-10-29 12:41:31              400100
#
#              DEVICE DEVICE_OS               RESPONSE_STATUS_NAME  \
# 990       iPhone XR    13.1.3             Successful validation.
# 991   iPhone 8 Plus    12.4.1             Successful validation.
# 992   iPhone 8 Plus    13.1.2  Documents successfully submitted.
# 993  iPhone 6s Plus    13.1.3  Documents successfully submitted.
# 994   iPhone XS Max    13.1.2     INFORMATION_NOT_VERIFIED_TITLE
# 995  iPhone 6s Plus    13.1.3             Successful validation.
# 996   iPhone XS Max    13.1.2             Successful validation.
# 997   iPhone 8 Plus    13.1.2             Successful validation.
# 998  iPhone 6s Plus    13.1.3  Documents successfully submitted.
# 999   iPhone 8 Plus    13.1.2  Documents successfully submitted.
#
#                      MOBILE_SUBMISSION_ID                              Size  \
# 990                                   NaN                               NaN
# 991                                   NaN                               NaN
# 992  07fe954f-1fd9-445c-9c48-8a2d94c62fea  submission - images size 3671216
# 993  d618a6d7-903c-443f-916f-932be7c0fcbe  submission - images size 1990752
# 994                                   NaN                               NaN
# 995                                   NaN                               NaN
# 996                                   NaN                               NaN
# 997                                   NaN                               NaN
# 998  98e85990-cf29-4244-a9c7-42a65b5cd8c0  submission - images size 1832128
# 999  5d9d9d4e-f0b5-4814-98bd-7647d2fe8052  submission - images size 9717728
#
#                          Page Count         INSERT_TS.1      LAST_UPDATE_TS  \
# 990                             NaN 2019-10-29 12:36:47 2019-10-29 12:36:50
# 991                             NaN 2019-10-29 12:37:25 2019-10-29 12:37:29
# 992  submission - images received 2 2019-10-29 12:37:34 2019-10-29 12:37:35
# 993  submission - images received 1 2019-10-29 12:37:37 2019-10-29 12:37:38
# 994                             NaN 2019-10-29 12:37:49 2019-10-29 12:37:53
# 995                             NaN 2019-10-29 12:38:43 2019-10-29 12:38:43
# 996                             NaN 2019-10-29 12:38:53 2019-10-29 12:38:53
# 997                             NaN 2019-10-29 12:38:56 2019-10-29 12:38:56
# 998  submission - images received 1 2019-10-29 12:39:18 2019-10-29 12:39:19
# 999  submission - images received 5 2019-10-29 12:41:31 2019-10-29 12:41:32
#
#          CLIENT_VERSION
# 990  1.0.201910230000.2
# 991  1.0.201910230000.2
# 992  1.0.201910230000.2
# 993  1.0.201910230000.2
# 994  1.0.201910230000.2
# 995  1.0.201910230000.2
# 996  1.0.201910230000.2
# 997  1.0.201910230000.2
# 998  1.0.201910230000.2
# 999  1.0.201910230000.2

# %%
df = df.drop(columns=["RESPONSE_STATUS_NAME", "MOBILE_APP_REQUEST_ID", "INSERT_TS.1"])
df.head()
# Out:
#             INSERT_TS  RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# 0 2019-10-28 02:02:27              300100  iPhone 6s Plus    13.1.3
# 1 2019-10-28 07:25:18              300100       SM-N960U1        28
# 2 2019-10-28 08:05:07              300100        SM-G960U        28
# 3 2019-10-28 08:32:42              300100        SM-G960U        28
# 4 2019-10-28 08:33:43              300200        SM-G960U        28
#
#   MOBILE_SUBMISSION_ID Size Page Count      LAST_UPDATE_TS      CLIENT_VERSION
# 0                  NaN  NaN        NaN 2019-10-28 02:02:29  1.0.201910230000.2
# 1                  NaN  NaN        NaN 2019-10-28 07:25:21                 1.0
# 2                  NaN  NaN        NaN 2019-10-28 08:05:12                 1.0
# 3                  NaN  NaN        NaN 2019-10-28 08:32:46                 1.0
# 4                  NaN  NaN        NaN 2019-10-28 08:33:47                 1.0

# %%
df.dtypes
# Out:
# INSERT_TS               datetime64[ns]
# RESPONSE_STATUS_ID               int64
# DEVICE                          object
# DEVICE_OS                       object
# MOBILE_SUBMISSION_ID            object
# Size                            object
# Page Count                      object
# LAST_UPDATE_TS          datetime64[ns]
# CLIENT_VERSION                  object
# dtype: object

# %%
df['LAST_UPDATE_TS'].sub(df['INSERT_TS'], axis=0)
# Out:
# 0     00:00:02
# 1     00:00:03
# 2     00:00:05
# 3     00:00:04
# 4     00:00:04
#         ...
# 995   00:00:00
# 996   00:00:00
# 997   00:00:00
# 998   00:00:01
# 999   00:00:01
# Length: 1000, dtype: timedelta64[ns]

# %%
df["Page Count"] = df["Page Count"].str.extract(r'\b(\w+)$', expand=True)

# %%
df["Size"] = df["Size"].str.extract(r'\b(\w+)$', expand=True)
df.head(20)
# Out:
#              INSERT_TS  RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# 0  2019-10-28 02:02:27              300100  iPhone 6s Plus    13.1.3
# 1  2019-10-28 07:25:18              300100       SM-N960U1        28
# 2  2019-10-28 08:05:07              300100        SM-G960U        28
# 3  2019-10-28 08:32:42              300100        SM-G960U        28
# 4  2019-10-28 08:33:43              300200        SM-G960U        28
# 5  2019-10-28 08:34:22              300100        SM-G960U        28
# 6  2019-10-28 08:57:13              300100   iPhone XS Max    13.1.3
# 7  2019-10-28 08:59:24              300100       iPhone XR    13.1.2
# 8  2019-10-28 08:59:28              400205   iPhone XS Max    13.1.3
# 9  2019-10-28 09:00:34              400205   iPhone XS Max    13.1.3
# 10 2019-10-28 09:02:49              400205   iPhone XS Max    13.1.3
# 11 2019-10-28 09:04:58              300200   iPhone 8 Plus    13.1.2
# 12 2019-10-28 09:05:28              400100   iPhone XS Max    13.1.3
# 13 2019-10-28 09:07:18              300200   iPhone 8 Plus    13.1.2
# 14 2019-10-28 09:08:27              300200   iPhone 8 Plus    13.1.2
# 15 2019-10-28 09:14:48              300100       iPhone XR    13.1.3
# 16 2019-10-28 09:15:51              300100        iPhone 8    13.1.3
# 17 2019-10-28 09:21:51              300200       iPhone XS    13.1.3
# 18 2019-10-28 09:22:41              300200  iPhone 6s Plus    13.1.3
# 19 2019-10-28 09:23:05              300100       iPhone XS    13.1.3
#
#                     MOBILE_SUBMISSION_ID      Size Page Count  \
# 0                                    NaN       NaN        NaN
# 1                                    NaN       NaN        NaN
# 2                                    NaN       NaN        NaN
# 3                                    NaN       NaN        NaN
# 4                                    NaN       NaN        NaN
# 5                                    NaN       NaN        NaN
# 6                                    NaN       NaN        NaN
# 7                                    NaN       NaN        NaN
# 8   c1420977-bc86-4734-9a1a-29a0b9953eed  10155392          4
# 9   bdb42832-2815-4798-a066-6b75963d459f  10155392          4
# 10  8244036c-41be-4072-8d42-deec628d160a  10155392          4
# 11                                   NaN       NaN        NaN
# 12  c6c607f2-0c56-4cfb-a627-aeef3f63697d   9031376          4
# 13                                   NaN       NaN        NaN
# 14                                   NaN       NaN        NaN
# 15                                   NaN       NaN        NaN
# 16                                   NaN       NaN        NaN
# 17                                   NaN       NaN        NaN
# 18                                   NaN       NaN        NaN
# 19                                   NaN       NaN        NaN
#
#         LAST_UPDATE_TS      CLIENT_VERSION
# 0  2019-10-28 02:02:29  1.0.201910230000.2
# 1  2019-10-28 07:25:21                 1.0
# 2  2019-10-28 08:05:12                 1.0
# 3  2019-10-28 08:32:46                 1.0
# 4  2019-10-28 08:33:47                 1.0
# 5  2019-10-28 08:34:22                 1.0
# 6  2019-10-28 08:57:17  1.0.201910230000.2
# 7  2019-10-28 08:59:28  1.0.201910230000.2
# 8  2019-10-28 08:59:29  1.0.201910230000.2
# 9  2019-10-28 09:00:35  1.0.201910230000.2
# 10 2019-10-28 09:02:49  1.0.201910230000.2
# 11 2019-10-28 09:05:06  1.0.201910230000.2
# 12 2019-10-28 09:05:29  1.0.201910230000.2
# 13 2019-10-28 09:07:19  1.0.201910230000.2
# 14 2019-10-28 09:08:27  1.0.201910230000.2
# 15 2019-10-28 09:14:51  1.0.201910230000.2
# 16 2019-10-28 09:15:55  1.0.201910230000.2
# 17 2019-10-28 09:21:54  1.0.201910230000.2
# 18 2019-10-28 09:23:27  1.0.201910230000.2
# 19 2019-10-28 09:23:05  1.0.201910230000.2

# %%
df.dtypes
# Out:
# INSERT_TS               datetime64[ns]
# RESPONSE_STATUS_ID               int64
# DEVICE                          object
# DEVICE_OS                       object
# MOBILE_SUBMISSION_ID            object
# Size                            object
# Page Count                      object
# LAST_UPDATE_TS          datetime64[ns]
# CLIENT_VERSION                  object
# dtype: object

# %%
df["Size"] = pd.to_numeric(df.Size)
df["Page Count"] = pd.to_numeric(df["Page Count"])
df.dtypes
# Out:
# INSERT_TS               datetime64[ns]
# RESPONSE_STATUS_ID               int64
# DEVICE                          object
# DEVICE_OS                       object
# MOBILE_SUBMISSION_ID            object
# Size                           float64
# Page Count                     float64
# LAST_UPDATE_TS          datetime64[ns]
# CLIENT_VERSION                  object
# dtype: object

# %%
df["Size"].fillna(0, inplace=True)
df["Page Count"].fillna(0, inplace=True)

# %%
df["Size"] = df["Size"].astype(int)
df["Page Count"] = df["Page Count"].astype(int)
df.head(20)
# Out:
#              INSERT_TS  RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# 0  2019-10-28 02:02:27              300100  iPhone 6s Plus    13.1.3
# 1  2019-10-28 07:25:18              300100       SM-N960U1        28
# 2  2019-10-28 08:05:07              300100        SM-G960U        28
# 3  2019-10-28 08:32:42              300100        SM-G960U        28
# 4  2019-10-28 08:33:43              300200        SM-G960U        28
# 5  2019-10-28 08:34:22              300100        SM-G960U        28
# 6  2019-10-28 08:57:13              300100   iPhone XS Max    13.1.3
# 7  2019-10-28 08:59:24              300100       iPhone XR    13.1.2
# 8  2019-10-28 08:59:28              400205   iPhone XS Max    13.1.3
# 9  2019-10-28 09:00:34              400205   iPhone XS Max    13.1.3
# 10 2019-10-28 09:02:49              400205   iPhone XS Max    13.1.3
# 11 2019-10-28 09:04:58              300200   iPhone 8 Plus    13.1.2
# 12 2019-10-28 09:05:28              400100   iPhone XS Max    13.1.3
# 13 2019-10-28 09:07:18              300200   iPhone 8 Plus    13.1.2
# 14 2019-10-28 09:08:27              300200   iPhone 8 Plus    13.1.2
# 15 2019-10-28 09:14:48              300100       iPhone XR    13.1.3
# 16 2019-10-28 09:15:51              300100        iPhone 8    13.1.3
# 17 2019-10-28 09:21:51              300200       iPhone XS    13.1.3
# 18 2019-10-28 09:22:41              300200  iPhone 6s Plus    13.1.3
# 19 2019-10-28 09:23:05              300100       iPhone XS    13.1.3
#
#                     MOBILE_SUBMISSION_ID      Size  Page Count  \
# 0                                    NaN         0           0
# 1                                    NaN         0           0
# 2                                    NaN         0           0
# 3                                    NaN         0           0
# 4                                    NaN         0           0
# 5                                    NaN         0           0
# 6                                    NaN         0           0
# 7                                    NaN         0           0
# 8   c1420977-bc86-4734-9a1a-29a0b9953eed  10155392           4
# 9   bdb42832-2815-4798-a066-6b75963d459f  10155392           4
# 10  8244036c-41be-4072-8d42-deec628d160a  10155392           4
# 11                                   NaN         0           0
# 12  c6c607f2-0c56-4cfb-a627-aeef3f63697d   9031376           4
# 13                                   NaN         0           0
# 14                                   NaN         0           0
# 15                                   NaN         0           0
# 16                                   NaN         0           0
# 17                                   NaN         0           0
# 18                                   NaN         0           0
# 19                                   NaN         0           0
#
#         LAST_UPDATE_TS      CLIENT_VERSION
# 0  2019-10-28 02:02:29  1.0.201910230000.2
# 1  2019-10-28 07:25:21                 1.0
# 2  2019-10-28 08:05:12                 1.0
# 3  2019-10-28 08:32:46                 1.0
# 4  2019-10-28 08:33:47                 1.0
# 5  2019-10-28 08:34:22                 1.0
# 6  2019-10-28 08:57:17  1.0.201910230000.2
# 7  2019-10-28 08:59:28  1.0.201910230000.2
# 8  2019-10-28 08:59:29  1.0.201910230000.2
# 9  2019-10-28 09:00:35  1.0.201910230000.2
# 10 2019-10-28 09:02:49  1.0.201910230000.2
# 11 2019-10-28 09:05:06  1.0.201910230000.2
# 12 2019-10-28 09:05:29  1.0.201910230000.2
# 13 2019-10-28 09:07:19  1.0.201910230000.2
# 14 2019-10-28 09:08:27  1.0.201910230000.2
# 15 2019-10-28 09:14:51  1.0.201910230000.2
# 16 2019-10-28 09:15:55  1.0.201910230000.2
# 17 2019-10-28 09:21:54  1.0.201910230000.2
# 18 2019-10-28 09:23:27  1.0.201910230000.2
# 19 2019-10-28 09:23:05  1.0.201910230000.2

# %%
df.dtypes
# Out:
# INSERT_TS               datetime64[ns]
# RESPONSE_STATUS_ID               int64
# DEVICE                          object
# DEVICE_OS                       object
# MOBILE_SUBMISSION_ID            object
# Size                             int64
# Page Count                       int64
# LAST_UPDATE_TS          datetime64[ns]
# CLIENT_VERSION                  object
# dtype: object

# %%
print ("Number of Unsuccessful Logins: ",df[ df["RESPONSE_STATUS_ID"] == 300200 ].shape[0])
print ("Number of Successful Logins: ",df[ df["RESPONSE_STATUS_ID"] == 300100 ].shape[0])
df_submit = df[ df["RESPONSE_STATUS_ID"] == 400100 ]["Page Count"]
print ("Number of Submissions: ",df_submit.shape[0])
print ("Number of Pages Submitted: ",df["Page Count"].sum())
print ("Number of iOS Devices:", df[ df["CLIENT_VERSION"] == "1.0.201910230000.2" ].shape[0] )
print ("Number of Android Devices:", df[ df["CLIENT_VERSION"] == "1.0" ].shape[0]  )
# Out:
# Number of Unsuccessful Logins:  249
# Number of Successful Logins:  437
# Number of Submissions:  288
# Number of Pages Submitted:  549
# Number of iOS Devices: 593
# Number of Android Devices: 407

# %%
df_submit.describe()
# Out:
# count    288.000000
# mean       1.440972
# std        0.877509
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        6.000000
# Name: Page Count, dtype: float64

# %%
df["Size"]/1000000.
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 995    0.000000
# 996    0.000000
# 997    0.000000
# 998    1.832128
# 999    9.717728
# Name: Size, Length: 1000, dtype: float64

# %%
df_submit.plot.hist(bins=5, alpha=0.5)

# %%
device = df.groupby(["DEVICE"])["DEVICE"].count()
device = device.sort_values(ascending = False).head(20)
device
# Out:
# DEVICE
# iPhone XR           132
# iPhone 8 Plus       107
# iPhone 7 Plus        57
# iPhone 8             54
# iPhone XS Max        54
# iPhone 7             41
# SM-G960U             31
# iPhone X             31
# iPhone 6s            28
# SM-N960U             26
# SM-G955U             23
# iPhone XS            20
# iPhone 6s Plus       20
# moto g(7) power      19
# SM-G965U             17
# SM-G950U             16
# iPhone SE            16
# SM-G975U             14
# iPhone12,5           13
# SAMSUNG-SM-J327A     12
# Name: DEVICE, dtype: int64

# %%
logins = df[ (df["RESPONSE_STATUS_ID"] == 300200) | (df["RESPONSE_STATUS_ID"] == 300100) ]
logins.shape
# Out:
# (686, 9)

# %%
logins.head(20)
# Out:
#              INSERT_TS  RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# 0  2019-10-28 02:02:27              300100  iPhone 6s Plus    13.1.3
# 1  2019-10-28 07:25:18              300100       SM-N960U1        28
# 2  2019-10-28 08:05:07              300100        SM-G960U        28
# 3  2019-10-28 08:32:42              300100        SM-G960U        28
# 4  2019-10-28 08:33:43              300200        SM-G960U        28
# 5  2019-10-28 08:34:22              300100        SM-G960U        28
# 6  2019-10-28 08:57:13              300100   iPhone XS Max    13.1.3
# 7  2019-10-28 08:59:24              300100       iPhone XR    13.1.2
# 11 2019-10-28 09:04:58              300200   iPhone 8 Plus    13.1.2
# 13 2019-10-28 09:07:18              300200   iPhone 8 Plus    13.1.2
# 14 2019-10-28 09:08:27              300200   iPhone 8 Plus    13.1.2
# 15 2019-10-28 09:14:48              300100       iPhone XR    13.1.3
# 16 2019-10-28 09:15:51              300100        iPhone 8    13.1.3
# 17 2019-10-28 09:21:51              300200       iPhone XS    13.1.3
# 18 2019-10-28 09:22:41              300200  iPhone 6s Plus    13.1.3
# 19 2019-10-28 09:23:05              300100       iPhone XS    13.1.3
# 20 2019-10-28 09:23:07              300200         LG-H918        26
# 22 2019-10-28 09:26:02              300100  iPhone 6s Plus    13.1.3
# 23 2019-10-28 09:26:20              300100         LG-H918        26
# 24 2019-10-28 09:26:44              300100       iPhone XS    13.1.3
#
#    MOBILE_SUBMISSION_ID  Size  Page Count      LAST_UPDATE_TS  \
# 0                   NaN     0           0 2019-10-28 02:02:29
# 1                   NaN     0           0 2019-10-28 07:25:21
# 2                   NaN     0           0 2019-10-28 08:05:12
# 3                   NaN     0           0 2019-10-28 08:32:46
# 4                   NaN     0           0 2019-10-28 08:33:47
# 5                   NaN     0           0 2019-10-28 08:34:22
# 6                   NaN     0           0 2019-10-28 08:57:17
# 7                   NaN     0           0 2019-10-28 08:59:28
# 11                  NaN     0           0 2019-10-28 09:05:06
# 13                  NaN     0           0 2019-10-28 09:07:19
# 14                  NaN     0           0 2019-10-28 09:08:27
# 15                  NaN     0           0 2019-10-28 09:14:51
# 16                  NaN     0           0 2019-10-28 09:15:55
# 17                  NaN     0           0 2019-10-28 09:21:54
# 18                  NaN     0           0 2019-10-28 09:23:27
# 19                  NaN     0           0 2019-10-28 09:23:05
# 20                  NaN     0           0 2019-10-28 09:24:43
# 22                  NaN     0           0 2019-10-28 09:26:04
# 23                  NaN     0           0 2019-10-28 09:26:22
# 24                  NaN     0           0 2019-10-28 09:26:48
#
#         CLIENT_VERSION
# 0   1.0.201910230000.2
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# 5                  1.0
# 6   1.0.201910230000.2
# 7   1.0.201910230000.2
# 11  1.0.201910230000.2
# 13  1.0.201910230000.2
# 14  1.0.201910230000.2
# 15  1.0.201910230000.2
# 16  1.0.201910230000.2
# 17  1.0.201910230000.2
# 18  1.0.201910230000.2
# 19  1.0.201910230000.2
# 20                 1.0
# 22  1.0.201910230000.2
# 23                 1.0
# 24  1.0.201910230000.2

# %%
iP8 = logins[ (logins["DEVICE"]=="iPhone 8 Plus") & (logins["RESPONSE_STATUS_ID"] == 300100) ]

# %%
iP8["Time_Lag"] = iP8["INSERT_TS"] - iP8["INSERT_TS"].shift(1)
# Out:
# /Users/danielchan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
iP8["Time_Lag"].dt.total_seconds()
# Out:
# 40         NaN
# 83      4030.0
# 84        26.0
# 93       687.0
# 189     4105.0
# 196      424.0
# 223     1836.0
# 244     1189.0
# 297     2738.0
# 317     1711.0
# 319      197.0
# 358     2513.0
# 452     4229.0
# 463      567.0
# 467      219.0
# 517     3930.0
# 521       87.0
# 622     9755.0
# 696    15779.0
# 697      929.0
# 737    29556.0
# 742      385.0
# 818     3719.0
# 836      662.0
# 838       22.0
# 849      622.0
# 850       32.0
# 851       18.0
# 858      680.0
# 880      887.0
# 914     2564.0
# 925      486.0
# 942      444.0
# 949      227.0
# 955       80.0
# 988     1277.0
# 991       51.0
# 997       91.0
# Name: Time_Lag, dtype: float64

# %%
iP8["Time_Lag"]
# Out:
# 40         NaT
# 83    01:07:10
# 84    00:00:26
# 93    00:11:27
# 189   01:08:25
# 196   00:07:04
# 223   00:30:36
# 244   00:19:49
# 297   00:45:38
# 317   00:28:31
# 319   00:03:17
# 358   00:41:53
# 452   01:10:29
# 463   00:09:27
# 467   00:03:39
# 517   01:05:30
# 521   00:01:27
# 622   02:42:35
# 696   04:22:59
# 697   00:15:29
# 737   08:12:36
# 742   00:06:25
# 818   01:01:59
# 836   00:11:02
# 838   00:00:22
# 849   00:10:22
# 850   00:00:32
# 851   00:00:18
# 858   00:11:20
# 880   00:14:47
# 914   00:42:44
# 925   00:08:06
# 942   00:07:24
# 949   00:03:47
# 955   00:01:20
# 988   00:21:17
# 991   00:00:51
# 997   00:01:31
# Name: Time_Lag, dtype: timedelta64[ns]

# %%
df.head(20)
# Out:
#              INSERT_TS  RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# 0  2019-10-28 02:02:27              300100  iPhone 6s Plus    13.1.3
# 1  2019-10-28 07:25:18              300100       SM-N960U1        28
# 2  2019-10-28 08:05:07              300100        SM-G960U        28
# 3  2019-10-28 08:32:42              300100        SM-G960U        28
# 4  2019-10-28 08:33:43              300200        SM-G960U        28
# 5  2019-10-28 08:34:22              300100        SM-G960U        28
# 6  2019-10-28 08:57:13              300100   iPhone XS Max    13.1.3
# 7  2019-10-28 08:59:24              300100       iPhone XR    13.1.2
# 8  2019-10-28 08:59:28              400205   iPhone XS Max    13.1.3
# 9  2019-10-28 09:00:34              400205   iPhone XS Max    13.1.3
# 10 2019-10-28 09:02:49              400205   iPhone XS Max    13.1.3
# 11 2019-10-28 09:04:58              300200   iPhone 8 Plus    13.1.2
# 12 2019-10-28 09:05:28              400100   iPhone XS Max    13.1.3
# 13 2019-10-28 09:07:18              300200   iPhone 8 Plus    13.1.2
# 14 2019-10-28 09:08:27              300200   iPhone 8 Plus    13.1.2
# 15 2019-10-28 09:14:48              300100       iPhone XR    13.1.3
# 16 2019-10-28 09:15:51              300100        iPhone 8    13.1.3
# 17 2019-10-28 09:21:51              300200       iPhone XS    13.1.3
# 18 2019-10-28 09:22:41              300200  iPhone 6s Plus    13.1.3
# 19 2019-10-28 09:23:05              300100       iPhone XS    13.1.3
#
#                     MOBILE_SUBMISSION_ID      Size  Page Count  \
# 0                                    NaN         0           0
# 1                                    NaN         0           0
# 2                                    NaN         0           0
# 3                                    NaN         0           0
# 4                                    NaN         0           0
# 5                                    NaN         0           0
# 6                                    NaN         0           0
# 7                                    NaN         0           0
# 8   c1420977-bc86-4734-9a1a-29a0b9953eed  10155392           4
# 9   bdb42832-2815-4798-a066-6b75963d459f  10155392           4
# 10  8244036c-41be-4072-8d42-deec628d160a  10155392           4
# 11                                   NaN         0           0
# 12  c6c607f2-0c56-4cfb-a627-aeef3f63697d   9031376           4
# 13                                   NaN         0           0
# 14                                   NaN         0           0
# 15                                   NaN         0           0
# 16                                   NaN         0           0
# 17                                   NaN         0           0
# 18                                   NaN         0           0
# 19                                   NaN         0           0
#
#         LAST_UPDATE_TS      CLIENT_VERSION
# 0  2019-10-28 02:02:29  1.0.201910230000.2
# 1  2019-10-28 07:25:21                 1.0
# 2  2019-10-28 08:05:12                 1.0
# 3  2019-10-28 08:32:46                 1.0
# 4  2019-10-28 08:33:47                 1.0
# 5  2019-10-28 08:34:22                 1.0
# 6  2019-10-28 08:57:17  1.0.201910230000.2
# 7  2019-10-28 08:59:28  1.0.201910230000.2
# 8  2019-10-28 08:59:29  1.0.201910230000.2
# 9  2019-10-28 09:00:35  1.0.201910230000.2
# 10 2019-10-28 09:02:49  1.0.201910230000.2
# 11 2019-10-28 09:05:06  1.0.201910230000.2
# 12 2019-10-28 09:05:29  1.0.201910230000.2
# 13 2019-10-28 09:07:19  1.0.201910230000.2
# 14 2019-10-28 09:08:27  1.0.201910230000.2
# 15 2019-10-28 09:14:51  1.0.201910230000.2
# 16 2019-10-28 09:15:55  1.0.201910230000.2
# 17 2019-10-28 09:21:54  1.0.201910230000.2
# 18 2019-10-28 09:23:27  1.0.201910230000.2
# 19 2019-10-28 09:23:05  1.0.201910230000.2

# %%
df_Copy = df.copy()

# %%
df["RESPONSE_STATUS_ID"] = df["RESPONSE_STATUS_ID"].replace( [300200,300100,300202,400205,400100,], [1,2,3,4,5])

# %%
df.groupby(["RESPONSE_STATUS_ID"])["RESPONSE_STATUS_ID"].count()
# Out:
# RESPONSE_STATUS_ID
# 1    249
# 2    437
# 3      2
# 4     24
# 5    288
# Name: RESPONSE_STATUS_ID, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# INSERT_TS               1000 non-null datetime64[ns]
# RESPONSE_STATUS_ID      1000 non-null int64
# DEVICE                  1000 non-null object
# DEVICE_OS               1000 non-null object
# MOBILE_SUBMISSION_ID    312 non-null object
# Size                    1000 non-null int64
# Page Count              1000 non-null int64
# LAST_UPDATE_TS          1000 non-null datetime64[ns]
# CLIENT_VERSION          1000 non-null object
# dtypes: datetime64[ns](2), int64(3), object(4)
# memory usage: 70.4+ KB

# %%
df.set_index("INSERT_TS", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1000 entries, 2019-10-28 02:02:27 to 2019-10-29 12:41:31
# Data columns (total 8 columns):
# RESPONSE_STATUS_ID      1000 non-null int64
# DEVICE                  1000 non-null object
# DEVICE_OS               1000 non-null object
# MOBILE_SUBMISSION_ID    312 non-null object
# Size                    1000 non-null int64
# Page Count              1000 non-null int64
# LAST_UPDATE_TS          1000 non-null datetime64[ns]
# CLIENT_VERSION          1000 non-null object
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 70.3+ KB

# %%
df.head(20)
# Out:
#                      RESPONSE_STATUS_ID          DEVICE DEVICE_OS  \
# INSERT_TS
# 2019-10-28 02:02:27                   2  iPhone 6s Plus    13.1.3
# 2019-10-28 07:25:18                   2       SM-N960U1        28
# 2019-10-28 08:05:07                   2        SM-G960U        28
# 2019-10-28 08:32:42                   2        SM-G960U        28
# 2019-10-28 08:33:43                   1        SM-G960U        28
# 2019-10-28 08:34:22                   2        SM-G960U        28
# 2019-10-28 08:57:13                   2   iPhone XS Max    13.1.3
# 2019-10-28 08:59:24                   2       iPhone XR    13.1.2
# 2019-10-28 08:59:28                   4   iPhone XS Max    13.1.3
# 2019-10-28 09:00:34                   4   iPhone XS Max    13.1.3
# 2019-10-28 09:02:49                   4   iPhone XS Max    13.1.3
# 2019-10-28 09:04:58                   1   iPhone 8 Plus    13.1.2
# 2019-10-28 09:05:28                   5   iPhone XS Max    13.1.3
# 2019-10-28 09:07:18                   1   iPhone 8 Plus    13.1.2
# 2019-10-28 09:08:27                   1   iPhone 8 Plus    13.1.2
# 2019-10-28 09:14:48                   2       iPhone XR    13.1.3
# 2019-10-28 09:15:51                   2        iPhone 8    13.1.3
# 2019-10-28 09:21:51                   1       iPhone XS    13.1.3
# 2019-10-28 09:22:41                   1  iPhone 6s Plus    13.1.3
# 2019-10-28 09:23:05                   2       iPhone XS    13.1.3
#
#                                      MOBILE_SUBMISSION_ID      Size  \
# INSERT_TS
# 2019-10-28 02:02:27                                   NaN         0
# 2019-10-28 07:25:18                                   NaN         0
# 2019-10-28 08:05:07                                   NaN         0
# 2019-10-28 08:32:42                                   NaN         0
# 2019-10-28 08:33:43                                   NaN         0
# 2019-10-28 08:34:22                                   NaN         0
# 2019-10-28 08:57:13                                   NaN         0
# 2019-10-28 08:59:24                                   NaN         0
# 2019-10-28 08:59:28  c1420977-bc86-4734-9a1a-29a0b9953eed  10155392
# 2019-10-28 09:00:34  bdb42832-2815-4798-a066-6b75963d459f  10155392
# 2019-10-28 09:02:49  8244036c-41be-4072-8d42-deec628d160a  10155392
# 2019-10-28 09:04:58                                   NaN         0
# 2019-10-28 09:05:28  c6c607f2-0c56-4cfb-a627-aeef3f63697d   9031376
# 2019-10-28 09:07:18                                   NaN         0
# 2019-10-28 09:08:27                                   NaN         0
# 2019-10-28 09:14:48                                   NaN         0
# 2019-10-28 09:15:51                                   NaN         0
# 2019-10-28 09:21:51                                   NaN         0
# 2019-10-28 09:22:41                                   NaN         0
# 2019-10-28 09:23:05                                   NaN         0
#
#                      Page Count      LAST_UPDATE_TS      CLIENT_VERSION
# INSERT_TS
# 2019-10-28 02:02:27           0 2019-10-28 02:02:29  1.0.201910230000.2
# 2019-10-28 07:25:18           0 2019-10-28 07:25:21                 1.0
# 2019-10-28 08:05:07           0 2019-10-28 08:05:12                 1.0
# 2019-10-28 08:32:42           0 2019-10-28 08:32:46                 1.0
# 2019-10-28 08:33:43           0 2019-10-28 08:33:47                 1.0
# 2019-10-28 08:34:22           0 2019-10-28 08:34:22                 1.0
# 2019-10-28 08:57:13           0 2019-10-28 08:57:17  1.0.201910230000.2
# 2019-10-28 08:59:24           0 2019-10-28 08:59:28  1.0.201910230000.2
# 2019-10-28 08:59:28           4 2019-10-28 08:59:29  1.0.201910230000.2
# 2019-10-28 09:00:34           4 2019-10-28 09:00:35  1.0.201910230000.2
# 2019-10-28 09:02:49           4 2019-10-28 09:02:49  1.0.201910230000.2
# 2019-10-28 09:04:58           0 2019-10-28 09:05:06  1.0.201910230000.2
# 2019-10-28 09:05:28           4 2019-10-28 09:05:29  1.0.201910230000.2
# 2019-10-28 09:07:18           0 2019-10-28 09:07:19  1.0.201910230000.2
# 2019-10-28 09:08:27           0 2019-10-28 09:08:27  1.0.201910230000.2
# 2019-10-28 09:14:48           0 2019-10-28 09:14:51  1.0.201910230000.2
# 2019-10-28 09:15:51           0 2019-10-28 09:15:55  1.0.201910230000.2
# 2019-10-28 09:21:51           0 2019-10-28 09:21:54  1.0.201910230000.2
# 2019-10-28 09:22:41           0 2019-10-28 09:23:27  1.0.201910230000.2
# 2019-10-28 09:23:05           0 2019-10-28 09:23:05  1.0.201910230000.2

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})

# %%
#df["RESPONSE_STATUS_ID"].plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True))

df["RESPONSE_STATUS_ID"].plot(marker='*', linestyle='None',figsize=(11, 9))
